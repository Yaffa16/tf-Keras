# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaffa16/tf-Keras/blob/master/NN_on_CSV_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How to run a ML model on CSV data file
#
#
# *  We take in a CSV data file
# *  We try to predict one of the columns of the data by training the model on the other columns
# * We first import the data as a pandas data format
# * Then we convert the data into a numpy format to feed the keras/tensorflow
# * we create a model
# * we fit the model
# * Find the RMSE
# * See what the predictions look like

# %%
import tensorflow as tf
print("Tensor Flow Version: {}".format(tf.__version__))
# Out:
# Tensor Flow Version: 1.15.0

# %% [markdown]
# ### Simple Tensorflow Regression

# %% [markdown]
# Read the CSV file

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])


cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())
df[0:10]
# Out:
#     mpg  cylinders  displacement  ...  year  origin                       name
# 0  18.0          8         307.0  ...    70       1  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...    70       1          buick skylark 320
# 2  18.0          8         318.0  ...    70       1         plymouth satellite
# 3  16.0          8         304.0  ...    70       1              amc rebel sst
# 4  17.0          8         302.0  ...    70       1                ford torino
# 5  15.0          8         429.0  ...    70       1           ford galaxie 500
# 6  14.0          8         454.0  ...    70       1           chevrolet impala
# 7  14.0          8         440.0  ...    70       1          plymouth fury iii
# 8  14.0          8         455.0  ...    70       1           pontiac catalina
# 9  15.0          8         390.0  ...    70       1         amc ambassador dpl
#
# [10 rows x 9 columns]

# %% [markdown]
# Accesss the values for the columns that we need to train on and put it in x
# Put the y prediction values in y

# %%
# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# %% [markdown]
# Create the model

# %%
# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# Fit the model

# %%
model.fit(x,y,verbose=2,epochs=100)
# Out:
# Train on 398 samples
# Epoch 1/100
# 398/398 - 0s - loss: 17739.0752
# Epoch 2/100
# 398/398 - 0s - loss: 2686.9393
# Epoch 3/100
# 398/398 - 0s - loss: 414.2082
# Epoch 4/100
# 398/398 - 0s - loss: 255.1235
# Epoch 5/100
# 398/398 - 0s - loss: 190.0621
# Epoch 6/100
# 398/398 - 0s - loss: 154.6818
# Epoch 7/100
# 398/398 - 0s - loss: 140.7930
# Epoch 8/100
# 398/398 - 0s - loss: 138.6439
# Epoch 9/100
# 398/398 - 0s - loss: 134.9979
# Epoch 10/100
# 398/398 - 0s - loss: 131.8687
# Epoch 11/100
# 398/398 - 0s - loss: 129.7921
# Epoch 12/100
# 398/398 - 0s - loss: 127.4648
# Epoch 13/100
# 398/398 - 0s - loss: 125.4138
# Epoch 14/100
# 398/398 - 0s - loss: 121.7046
# Epoch 15/100
# 398/398 - 0s - loss: 121.5456
# Epoch 16/100
# 398/398 - 0s - loss: 117.7422
# Epoch 17/100
# 398/398 - 0s - loss: 115.2680
# Epoch 18/100
# 398/398 - 0s - loss: 113.0709
# Epoch 19/100
# 398/398 - 0s - loss: 110.2243
# Epoch 20/100
# 398/398 - 0s - loss: 106.8698
# Epoch 21/100
# ...

# %% [markdown]
# Predict the  values

# %%
pred = model.predict(x)
print("Shape: {}".format(pred.shape))
print(pred)
# Out:
# Shape: (398, 1)
# [[11.327271 ]
#  [10.593313 ]
#  [11.58159  ]
#  [13.307111 ]
#  [12.318388 ]
#  [ 7.2563095]
#  [ 6.477012 ]
#  [ 7.2673926]
#  [ 7.32076  ]
#  [ 8.593682 ]
#  [ 6.6643047]
#  [10.17171  ]
#  [ 3.529708 ]
#  [ 2.2664118]
#  [26.822721 ]
#  [18.369377 ]
#  [18.229248 ]
#  [16.364805 ]
#  [26.88504  ]
#  [22.588385 ]
#  [27.675879 ]
#  [26.76244  ]
#  [27.978926 ]
#  [26.287975 ]
#  [16.979095 ]
#  [18.292143 ]
#  [21.953812 ]
#  [21.424875 ]
#  [23.672417 ]
#  [27.13059  ]
#  [22.623676 ]
#  [26.319353 ]
#  [27.450096 ]
#  [14.110828 ]
#  [18.908407 ]
#  [15.278483 ]
#  [14.024624 ]
#  [17.092863 ]
#  [12.889316 ]
#  [ 9.238956 ]
#  [11.728431 ]
#  [14.729085 ]
#  [13.432146 ]
#  [ 9.92629  ]
#  [11.893391 ]
#  [13.566991 ]
#  [22.158165 ]
#  [14.998235 ]
#  [13.204046 ]
#  [23.734747 ]
#  [24.761896 ]
#  [27.83426  ]
#  [26.364962 ]
#  [27.319277 ]
#  [26.767124 ]
#  [23.874557 ]
#  [25.924677 ]
#  [27.061592 ]
#  [26.345716 ]
#  [26.075708 ]
#  [24.234064 ]
# ...

# %%
# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Final score (RMSE): {score}")
# Out:
# Final score (RMSE): 5.625576834426618

# %%
# Sample predictions
for i in range(10):
    print(f"{i+1}. Index: {cars[i]}, mpg: {y[i]}, predicted mpg: {pred[i]}")
# Out:
# 1. Index: chevrolet chevelle malibu, mpg: 18.0, predicted mpg: [11.327271]
# 2. Index: buick skylark 320, mpg: 15.0, predicted mpg: [10.593313]
# 3. Index: plymouth satellite, mpg: 18.0, predicted mpg: [11.58159]
# 4. Index: amc rebel sst, mpg: 16.0, predicted mpg: [13.307111]
# 5. Index: ford torino, mpg: 17.0, predicted mpg: [12.318388]
# 6. Index: ford galaxie 500, mpg: 15.0, predicted mpg: [7.2563095]
# 7. Index: chevrolet impala, mpg: 14.0, predicted mpg: [6.477012]
# 8. Index: plymouth fury iii, mpg: 14.0, predicted mpg: [7.2673926]
# 9. Index: pontiac catalina, mpg: 14.0, predicted mpg: [7.32076]
# 10. Index: amc ambassador dpl, mpg: 15.0, predicted mpg: [8.593682]
